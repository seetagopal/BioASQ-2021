# %% [markdown]
# <a href="https://colab.research.google.com/github/seetagopal/BioASQ-2021/blob/main/BioASQ_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import json
from pprint import pprint

# %%
def prep_factoid(data: dict, test_file: bool = False) -> dict:
    paragraphs = []
    for j, question in enumerate(data['questions']):

        if question['type'] == 'factoid':
            q_text = question['body'].replace(r'\u', '')
            id_base = question['id']
            #id = question['id']
            ideal = question['ideal_answer']
            exact = question['exact_answer']
            if test_file:
                exact = exact[0]
            for i, snippet in enumerate(question['snippets']):
                id = id_base + f'_{i+1:03}'
                context = snippet['text'].replace(r'\u', '')
                answer_start = -1
                is_impossible = False
                if not test_file:
                    for ans in set(ideal+exact):
                        ans = ans.replace(r'\u', '')
                        idx_found = context.lower().find(ans.lower())
                        if idx_found >= 0:
                            answer_start = idx_found
                            exact_answer = ans
                    if answer_start == -1:
                        is_impossible = True
                        continue
                    answers = [{
                        'text': exact_answer,
                        'answer_start': answer_start
                    }]
                else:
                    if len(id) != 28:
                        id = id + f'_{i+1:03}'
                    answers = []
                sample = {
                    'qas': [{
                        'id': id,
                        'question': q_text,
                        'answers': answers
                    }],
                    'context': context
                }
                paragraphs.append(sample)
    prepped_dict = {
        'data': [{
            'paragraphs': paragraphs
        }]
    }
    return prepped_dict

# %%
def prep_factoid_test(data: dict, test_file: bool = False) -> dict:
    paragraphs = []
    for j, question in enumerate(data['questions']):
        if question['type'] == 'factoid':
            q_text = question['body'].replace(r'\u', '')
            id_base = question['id']
            #id = question['id']
            #ideal = question['ideal_answer']
           # exact = question['exact_answer']
            if test_file:
                exact = exact[0]
            for i, snippet in enumerate(question['snippets']):
                id = id_base + f'_{i+1:03}'
                context = snippet['text'].replace(r'\u', '')
               # answer_start = -1
                #is_impossible = False
                # if not test_file:
                #     for ans in set(ideal+exact):
                #         ans = ans.replace(r'\u', '')
                #         idx_found = context.lower().find(ans.lower())
                #         if idx_found >= 0:
                #             answer_start = idx_found
                #             exact_answer = ans
                #     if answer_start == -1:
                #         is_impossible = True
                #         continue
                #     answers = [{
                #         'text': exact_answer,
                #         'answer_start': answer_start
                #     }]
                # else:
                #     if len(id) != 28:
                #         id = id + f'_{i+1:03}'
                #     answers = []
                sample = {
                    'qas': [{
                        'id': id,
                        'question': q_text,
                        #'answers': answers
                    }],
                    'context': context
                }
                paragraphs.append(sample)
    prepped_dict = {
        'data': [{
            'paragraphs': paragraphs
        }]
    }
    return prepped_dict

# %%
def prep_yesno(data: dict, test_file: bool = False) -> dict:
    paragraphs = []
    for j, question in enumerate(data['questions']):
        if question['type'] == 'yesno':
            q_text = question['body'].replace(r'\u', '')
            id_base = question['id']
            exact = question['exact_answer'] # yes or no
            for i, snippet in enumerate(question['snippets']):
                id = id_base + f'_{i+1:03}'
                context = snippet['text'].replace(r'\u', '')
                # if not test_file:
                if exact == 'yes':
                  is_impossible = False
                else:
                  is_impossible = True
                sample = {
                    'qas': [{
                        'id': id,
                        'question': q_text,
                        'is_impossible': is_impossible,
                        'answers': exact
                    }],
                    'context': context
                }
                # else:
                #     sample = {
                #         'qas': [{
                #             'id': id,
                #             'question': q_text,
                #         }],
                #         'context': context
                #     }
                paragraphs.append(sample)
    prepped_dict = {
        'data': [{
            'paragraphs': paragraphs
        }]
    }
    return prepped_dict

# %%
def prep_test_yesno(data: dict, test_file: bool = False) -> dict:
    paragraphs = []
    for j, question in enumerate(data['questions']):
        if question['type'] == 'yesno':
            q_text = question['body'].replace(r'\u', '')
            id_base = question['id']
            #exact = question['exact_answer'] # yes or no
            for i, snippet in enumerate(question['snippets']):
                id = id_base + f'_{i+1:03}'
                context = snippet['text'].replace(r'\u', '')
                # if not test_file:
                #is_impossible = False
                # if exact == 'yes':
                #   is_impossible = False
                # else:
                #   is_impossible = True
                sample = {
                    'qas': [{
                        'id': id,
                        'question': q_text,
                     #   'is_impossible': is_impossible,
                      #  'answers': exact
                    }],
                    'context': context
                }
                # else:
                #     sample = {
                #         'qas': [{
                #             'id': id,
                #             'question': q_text,
                #         }],
                #         'context': context
                #     }
                paragraphs.append(sample)
    prepped_dict = {
        'data': [{
            'paragraphs': paragraphs
        }]
    }
    return prepped_dict

# %%
with open('/content/training9b.json') as f:
    data = json.load(f)

prepped_data = prep_factoid(data)
#prepped_data_yesno = prep_yesno(data)
#print(prepped_data)

with open('prepped_training9b.json', 'w') as fn:
    # indent for formatting
    # ensure_ascii to exclude \u char from being written
    json.dump(prepped_data, fn)#, indent=2)#, ensure_ascii=False)

# %%
with open('/content/BioASQ-task9bPhaseB-testset5.txt') as f:
    data1 = json.load(f)

#prepped_data = prep_factoid(data)
prepped_test_data = prep_factoid_test(data1)
#print(prepped_data)

with open('prepped_test_factoid.json', 'w') as fn:
    # indent for formatting
    # ensure_ascii to exclude \u char from being written
    json.dump(prepped_test_data, fn)#, i

# %%
with open('/content/training9b.json') as f:
    data1 = json.load(f)

#prepped_data = prep_factoid(data)
prepped_train_yesno = prep_yesno(data1)
#print(prepped_data)

with open('prepped_train_yesno.json', 'w') as fn:
    # indent for formatting
    # ensure_ascii to exclude \u char from being written
    json.dump(prepped_train_yesno, fn)#, indent=2)#, ensure_ascii=False)

# %%
with open('/content/BioASQ-task9bPhaseB-testset5.txt') as f:
    data1 = json.load(f)

#prepped_data = prep_factoid(data)
prepped_test_yesno = prep_test_yesno(data1)
#print(prepped_data)

with open('prepped_test_yesno.json', 'w') as fn:
    # indent for formatting
    # ensure_ascii to exclude \u char from being written
    json.dump(prepped_test_yesno, fn)#, indent=2)#, ensure_ascii=False)

#!cp '/content/8B2_gol

# %%
# !gdown --id 1AR6CLa17oMjdnYtV1xF3w9GygSrElmxK
# !gdown --id 1rXFQRcV69QHAxghQ3NeAlhkg6ykpflVK
# !gdown --id 17fX1-oChZ5rxu-e-JuaZl2I96q1dGJO4
# !gdown --id 1GQUvBbXvlI_PeUPsZTqh7xQDZMOXh7ko
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1AR6CLa17oMjdnYtV1xF3w9GygSrElmxK
# To: /content/BERT-pubmed-1000000-SQuAD2.tar.gz
# 1.21GB [00:06, 189MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1rXFQRcV69QHAxghQ3NeAlhkg6ykpflVK
# To: /content/BERT-pubmed-1000000-SQuAD.tar.gz
# 1.21GB [00:28, 42.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=17fX1-oChZ5rxu-e-JuaZl2I96q1dGJO4
# To: /content/bert_config.json
# 100% 313/313 [00:00<00:00, 514kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1GQUvBbXvlI_PeUPsZTqh7xQDZMOXh7ko
# To: /content/vocab.txt
# 100% 213k/213k [00:00<00:00, 6.77MB/s]

# %%
#Squad pretrained weights for factoid and list
# !tar -xvzf /content/BERT-pubmed-1000000-SQuAD.tar.gz
# Out:
# checkpoint
# graph.pbtxt
# train.tf_record
# model.ckpt-14599.data-00000-of-00001
# model.ckpt-14599.index
# model.ckpt-14599.meta

# %%
# !mkdir /content/BERT-pubmed-1000000-SQuAD

# %%
#move the weights of factoid &list to the folder
# !mv /content/checkpoint /content/BERT-pubmed-1000000-SQuAD
# !mv /content/graph.pbtxt /content/BERT-pubmed-1000000-SQuAD
# !mv /content/train.tf_record /content/BERT-pubmed-1000000-SQuAD
# !mv /content/model.ckpt-14599.data-00000-of-00001 /content/BERT-pubmed-1000000-SQuAD
# !mv /content/model.ckpt-14599.index /content/BERT-pubmed-1000000-SQuAD
# !mv /content/model.ckpt-14599.meta /content/BERT-pubmed-1000000-SQuAD

# %%
#SQUAD pretrained weights for yes/no
# !tar -xvzf BERT-pubmed-1000000-SQuAD2.tar.gz
# Out:
# checkpoint
# graph.pbtxt
# train.tf_record
# model.ckpt-14470.data-00000-of-00001
# model.ckpt-14470.index
# model.ckpt-14470.meta

# %%
# !mkdir /content/BERT-pubmed-1000000-SQuAD2

# %%
# !mv /content/checkpoint /content/BERT-pubmed-1000000-SQuAD2
# !mv /content/graph.pbtxt /content/BERT-pubmed-1000000-SQuAD2
# !mv /content/train.tf_record /content/BERT-pubmed-1000000-SQuAD2
# !mv /content/model.ckpt-14470.data-00000-of-00001 /content/BERT-pubmed-1000000-SQuAD2
# !mv /content/model.ckpt-14470.index /content/BERT-pubmed-1000000-SQuAD2
# !mv /content/model.ckpt-14470.meta /content/BERT-pubmed-1000000-SQuAD2

# %%
# !python3.7 -m pip install tensorflow-gpu==1.15.0
# Out:
# ...
#      |████████████████████████████████| 411.5MB 42kB/s
# ...
#      |████████████████████████████████| 51kB 1.4MB/s
# ...
#      |████████████████████████████████| 512kB 58.7MB/s
# ...
#      |████████████████████████████████| 3.8MB 47.2MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=a99b62c8178e9453dde26d98ea476ca14be0db97a139cfc458eb2e608aa3c552
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.4.1 has requirement gast==0.3.3, but you'll have gast 0.2.2 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement tensorboard~=2.4, but you'll have tensorboard 1.15.0 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement tensorflow-estimator<2.5.0,>=2.4.0, but you'll have tensorflow-estimator 1.15.1 which is incompatible.
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...

# %%
# !git clone https://github.com/dmis-lab/bioasq-biobert.git
# Out:
# Cloning into 'bioasq-biobert'...
# remote: Enumerating objects: 74, done.
# remote: Total 74 (delta 0), reused 0 (delta 0), pack-reused 74
# Unpacking objects: 100% (74/74), done.

# %%
#run factoid
# !python /content/bioasq-biobert/run_factoid.py --do_train=True --do_predict=True --vocab_file=/content/vocab.txt --bert_config_file=/content/bert_config.json --init_checkpoint=/content/BERT-pubmed-1000000-SQuAD/model.ckpt-14599 --max_seq_length=384 --train_batch_size=12 --learning_rate=5e-6 --doc_stride=128 --num_train_epochs=5.0 --do_lower_case=False --train_file=/content/prepped_training9b.json --predict_file=/content/prepped_test_factoid.json --output_dir=/content
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:examples/sec: 10.1595
# I0506 19:32:14.199564 140114046797696 tpu_estimator.py:2308] examples/sec: 10.1595
# INFO:tensorflow:global_step/sec: 0.84363
# I0506 19:32:15.384676 140114046797696 tpu_estimator.py:2307] global_step/sec: 0.84363
# INFO:tensorflow:examples/sec: 10.1236
# I0506 19:32:15.385142 140114046797696 tpu_estimator.py:2308] examples/sec: 10.1236
# INFO:tensorflow:global_step/sec: 0.84211
# I0506 19:32:16.572151 140114046797696 tpu_estimator.py:2307] global_step/sec: 0.84211
# INFO:tensorflow:examples/sec: 10.1053
# I0506 19:32:16.572385 140114046797696 tpu_estimator.py:2308] examples/sec: 10.1053
# INFO:tensorflow:global_step/sec: 0.846653
# I0506 19:32:17.753265 140114046797696 tpu_estimator.py:2307] global_step/sec: 0.846653
# INFO:tensorflow:examples/sec: 10.1598
# I0506 19:32:17.753633 140114046797696 tpu_estimator.py:2308] examples/sec: 10.1598
# INFO:tensorflow:global_step/sec: 0.850902
# ...

# %%
#convert output into BioASQ format
# !python /content/bioasq-biobert/biocodes/transform_n2b_factoid.py --nbest_path=/content/nbest_predictions.json --output_path=/content

# %%
#run yes/no
# !python /content/bioasq-biobert/run_yesno.py \
     --do_train=True \
     --do_predict=True \
     --vocab_file=/content/vocab.txt \
     --bert_config_file=/content/bert_config.json \
     --init_checkpoint=/content/BERT-pubmed-1000000-SQuAD2/model.ckpt-14470 \
     --max_seq_length=384 \
     --train_batch_size=12 \
     --learning_rate=5e-6 \
     --doc_stride=128 \
     --num_train_epochs=5.0 \
     --do_lower_case=False \
     --train_file=/content/prepped_train_yesno.json \
     --predict_file=/content/prepped_test_yesno.json \
     --output_dir=/content
# Out:
# WARNING:tensorflow:From /content/bioasq-biobert/optimization.py:87: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /content/bioasq-biobert/run_yesno.py:1092: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/bioasq-biobert/modeling.py:92: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0506 20:07:17.302424 140489529694080 module_wrapper.py:139] From /content/bioasq-biobert/modeling.py:92: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# WARNING:tensorflow:From /content/bioasq-biobert/run_yesno.py:925: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# W0506 20:07:17.304078 140489529694080 module_wrapper.py:139] From /content/bioasq-biobert/run_yesno.py:925: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
#
# ...

# %%
#convert output into BioASQ format
# !python /content/bioasq-biobert/biocodes/transform_n2b_yesno.py --nbest_path=/content/predictions.json --output_path=/content
# Out:
# 19 number of questions

# %%
def prep_list(data: dict, test_file: bool = False) -> dict:
   paragraphs = []
   for j, question in enumerate(data['questions']):
 
       if question['type'] == 'factoid':
           q_text = question['body'].replace(r'\u', '')
           id_base = question['id']
           #id = question['id']
           ideal = question['ideal_answer']
           exact = question['exact_answer']
           if test_file:
               exact = exact[0]
           for i, snippet in enumerate(question['snippets']):
               id = id_base + f'_{i+1:03}'
               context = snippet['text'].replace(r'\u', '')
               answer_start = -1
               is_impossible = False
               if not test_file:
                   for ans in set(ideal+exact):
                       ans = ans.replace(r'\u', '')
                       idx_found = context.lower().find(ans.lower())
                       if idx_found >= 0:
                           answer_start = idx_found
                           exact_answer = ans
                   if answer_start == -1:
                       is_impossible = True
                       continue
                   answers = [{
                       'text': exact_answer,
                       'answer_start': answer_start
                   }]
               else:
                   if len(id) != 28:
                       id = id + f'_{i+1:03}'
                   answers = []
               sample = {
                   'qas': [{
                       'id': id,
                       'question': q_text,
                       'answers': answers
                   }],
                   'context': context
               }
               paragraphs.append(sample)
   prepped_dict = {
       'data': [{
           'paragraphs': paragraphs
       }]
   }
   return prepped_dict

# %%
def prep_list_test(data: dict, test_file: bool = False) -> dict:
   paragraphs = []
   for j, question in enumerate(data['questions']):
       if question['type'] == 'list':
           q_text = question['body'].replace(r'\u', '')
           id_base = question['id']
           #id = question['id']
           #ideal = question['ideal_answer']
          # exact = question['exact_answer']
           if test_file:
               exact = exact[0]
           for i, snippet in enumerate(question['snippets']):
               id = id_base + f'_{i+1:03}'
               context = snippet['text'].replace(r'\u', '')
              # answer_start = -1
               #is_impossible = False
               # if not test_file:
               #     for ans in set(ideal+exact):
               #         ans = ans.replace(r'\u', '')
               #         idx_found = context.lower().find(ans.lower())
               #         if idx_found >= 0:
               #             answer_start = idx_found
               #             exact_answer = ans
               #     if answer_start == -1:
               #         is_impossible = True
               #         continue
               #     answers = [{
               #         'text': exact_answer,
               #         'answer_start': answer_start
               #     }]
               # else:
               #     if len(id) != 28:
               #         id = id + f'_{i+1:03}'
               #     answers = []
               sample = {
                   'qas': [{
                       'id': id,
                       'question': q_text,
                       #'answers': answers
                   }],
                   'context': context
               }
               paragraphs.append(sample)
   prepped_dict = {
       'data': [{
           'paragraphs': paragraphs
       }]
   }
   return prepped_dict

# %%
with open('BioASQ-task9bPhaseB-testset5.txt') as f:
    data = json.load(f)

prepped_data = prep_list_test(data)
#prepped_data_yesno = prep_yesno(data)
#print(prepped_data)

with open('list.json', 'w') as fn:
    # indent for formatting
    # ensure_ascii to exclude \u char from being written
    json.dump(prepped_data, fn)

# %%
with open('/content/training9b.json') as f:
    data = json.load(f)

prepped_data = prep_list(data)
#prepped_data_yesno = prep_yesno(data)
#print(prepped_data)

with open('prepped_list_train.json', 'w') as fn:
    # indent for formatting
    # ensure_ascii to exclude \u char from being written
    json.dump(prepped_data, fn)

# %%
#run list
# !python /content/bioasq-biobert/run_list.py \
     --do_train=True \
     --do_predict=True \
     --vocab_file=/content/vocab.txt \
     --bert_config_file=/content/bert_config.json \
     --init_checkpoint=/content/BERT-pubmed-1000000-SQuAD/model.ckpt-14599 \
     --max_seq_length=384 \
     --train_batch_size=12 \
     --learning_rate=5e-6 \
     --doc_stride=128 \
     --num_train_epochs=5.0 \
     --do_lower_case=False \
     --train_file=/content/prepped_list_train.json \
     --predict_file=/content/list.json \
     --output_dir=/content
# Out:
# WARNING:tensorflow:From /content/bioasq-biobert/optimization.py:87: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /content/bioasq-biobert/run_list.py:1401: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/bioasq-biobert/run_list.py:1151: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# W0506 20:28:31.536067 139973891909504 module_wrapper.py:139] From /content/bioasq-biobert/run_list.py:1151: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /content/bioasq-biobert/run_list.py:1151: The name tf.logging.INFO is deprecated. Please use tf.compat.v1.logging.INFO instead.
#
# ...

# %%
#convert output into BioASQ format
# !python /content/bioasq-biobert/biocodes/transform_n2b_list.py --nbest_path=/content/nbest_predictions.json --output_path=/content
# Out:
# {'nbest_path': '/content/nbest_predictions.json', 'output_path': '/content', 'output_file': 'BioASQform_BioASQ-answer.json', 'threshold': 0.42, 'check_num_len': 4, 'use_softmax': False, 'min_prob': 0.02, 'stop_prob': 0.8, 'verbose': False}
# Threshold 0.42
# Found 2 qid 6028fc001cb411341a000102 q_text Which two antibodies directed towards the CGRP ligand, were approved by the FDA in September 2018.
# Found 3 qid 601f1bbd1cb411341a000074 q_text Please list 3 small molecule CGRP-Receptor antagonists for migraine
# Found 2 qid 5fdb43f6a43ad3127800002e q_text What are the two types of duplicated genes in the yeast S. cerevisiae?
# #questions 18

# %%
#data preparation for summary
def prep_summary_test(data: dict, test_file: bool = False) -> dict:
   paragraphs = []
   for j, question in enumerate(data['questions']):
       if question['type'] == 'summary':
           q_text = question['body'].replace(r'\u', '')
           id_base = question['id']
           #id = question['id']
           #ideal = question['ideal_answer']
          # exact = question['exact_answer']
           if test_file:
               exact = exact[0]
           for i, snippet in enumerate(question['snippets']):
               id = id_base + f'_{i+1:03}'
               context = snippet['text'].replace(r'\u', '')
              # answer_start = -1
               #is_impossible = False
               # if not test_file:
               #     for ans in set(ideal+exact):
               #         ans = ans.replace(r'\u', '')
               #         idx_found = context.lower().find(ans.lower())
               #         if idx_found >= 0:
               #             answer_start = idx_found
               #             exact_answer = ans
               #     if answer_start == -1:
               #         is_impossible = True
               #         continue
               #     answers = [{
               #         'text': exact_answer,
               #         'answer_start': answer_start
               #     }]
               # else:
               #     if len(id) != 28:
               #         id = id + f'_{i+1:03}'
               #     answers = []
               sample = {
                   'qas': [{
                       'id': id,
                       'question': q_text,
                       #'answers': answers
                   }],
                   'context': context
               }
               paragraphs.append(sample)
   prepped_dict = {
       'data': [{
           'paragraphs': paragraphs
       }]
   }
   return prepped_dict

# %%
with open('BioASQ-task9bPhaseB-testset5.txt') as f:
    data = json.load(f)
 
prepped_data = prep_summary_test(data)
#prepped_data_yesno = prep_yesno(data)
#print(prepped_data)
 
with open('BioASQform_BioASQ-answer_summary_testset5.json', 'w') as fn:
    # indent for formatting
    # ensure_ascii to exclude \u char from being written
    json.dump(prepped_data, fn)#, ind

# %%
cd /content
# Out:
# /content

# %%
#!python /content/run_summary.py --num_train_epochs=100.0 --do_predict=True --vocab_file=vocab.txt --bert_config_file=bert_config.json --init_checkpoint=model.ckpt-14470 --max_seq_length=384 --doc_stride=128 --do_lower_case=False --train_batch_size=10 --predict_batch_size=10 --train_file=prepped_factoid_training9b.json --predict_file=BioASQform_BioASQ-answer_summary_testset5.json --output_dir=/content

# %%
f1data = f2data = f3data = f4data = ""

# %%
with open('/content/BioASQform_BioASQ-answer_factoid_testset5.json') as f1: 
  f1data = f1.read() 
with open('/content/BioASQform_BioASQ-answer_yesno_testbatch5.json') as f2: 
  f2data = f2.read() 
with open('/content/BioASQform_BioASQ-answer_list_testbatch5.json') as f3: 
  f3data = f3.read() 
with open('/content/BioASQform_BioASQ-answer_summary.json') as f4: 
  f4data = f4.read()

# %%
f1data += "\n"
f1data += f2data
f1data += "\n"
f1data += f3data
f1data += "\n"
f1data += f4data
with open ('BioASQform_BioASQ-answer_final.json', 'a') as f5: 
  f5.write(f1data)
